# %%
def get_env_config(env):
    config = {
        "dev": {
            "catalog": "retail_dev",
            "schema": "sales"
        },
        "qa": {
            "catalog": "retail_qa",
            "schema": "sales"
        },
        "prod": {
            "catalog": "retail_prod",
            "schema": "sales"
        }
    }
    return config[env]
